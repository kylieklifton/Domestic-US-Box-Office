# %%
# Auto updating website visualizing the Domestic Film Box office, and possibly more
Title: 🎬 Best of the 2025 Domestic Box Office

# %% [markdown]
# # The problem
#
# There is a lot of data on websites like IMDB, Box Office Mojo (a product of IMDB), Rotten Tomatoes and more.
#
# However, these websites and simple entertainment coverage don't capitalize on the high visual potential that is possible with this data.
#
# I would also like to visualize global trends and more through multiple charts, but let's see how far I get.

# %% [markdown]
# # The Steps
#
# We need to abduct the data from at least one or more websites and make our own data visualization(s) of it.
#
# 1. Turn the website's data into a CSV of our own (in this case, we're going to scrape it!!)
# - Used `pd.read_html` to find all of the <table> elements
# - Grabbed the first table as our data
# - Cleaned it up a bit by renaming and removing columns
# - Saved it as `box-office.csv`
# 2. Make that update automatically!
# - Make it a GitHub repository
# - Turn on Github Actions
# - Set up yml file
#     - BE SURE TO MAKE SURE YOUR NOTEBOOK NAME MATCHES
# 3. Make a website
# - Index.html
# - Add it to your repo and push it up to github
# - Turn on github pages
# - Make sure your index.html by visiting the pages
# 4. Make a visualization for our webpage
# - Use datawrapper

# %% [markdown]
# # Data Collection
# I initially tried using another IMDB site, but it was blocking my scraping. https://www.imdb.com/chart/boxoffice/
#
# So I opted to use another IMDB resource and it wasn't blocked. I had the most success scraping Box Office Mojo which is a product of IMDB. https://www.boxofficemojo.com/date/?ref_=bo_nb_wey_secondarytab

# %% [markdown]
# # What I learned
#
# How to scrape on my own, build a website in Github and how to persevere with what's in front of me.
#
# There was a point in my data wrapper saga where I realized the numbers weren't formatting right so I had to go back and do multiple steps again. Next time I would be more careful with what data I clean before it turns into the CSV and maybe consider merging data sets so when it comes to designing in datawrapper I have more to pull from.

# %% [markdown]
# # What I would do differently next time
#
# This is by far not my strongest data analysis or chart for that matter. My main goal was to scrape properly and create a auto updating website. With more practice I know I can create multiple charts like I pitched that are more focused and truly communicate what audiences need to know about that day or week's box office.
#
# I'm still fond of this idea and want to return to try again in the future.
